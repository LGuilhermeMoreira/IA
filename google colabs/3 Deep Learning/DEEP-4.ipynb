# %% [markdown]
# # Entendendo Otimização de Modelo
#
# - Simultaneamente otimizando milhares de parâmetros com relacionamentos complexos não é uma tarefa fácil
# - Atualizações podem não melhorar o modelo significativamente
# - Atualizações muito pequenas (se a taxa de aprendizagem é baixa) ou muito grande (se a taxa de aprendizado é alta)

# %% [markdown]
# # Stochastic gradient descent

# %%
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
import pandas as pd

# %%
from keras import optimizers

# %%
def get_new_model(input_shape = input_shape):
    model = Sequential()
    model.add(Dense(100, activation='relu', input_shape = input_shape)) 
    model.add(Dense(100, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    return(model)

lr_to_test = [.000001, 0.01, 1]

# loop over learning rates
for lr in lr_to_test:
    model = get_new_model()
    my_optimizer = SGD(lr=lr)
    model.compile(optimizer = my_optimizer, loss = 'categorical_crossentropy') model.fit(predictors, target)
# Out:
#   File "<ipython-input-5-14adce0cc022>", line 2
#     model = Sequential()
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Vanishing gradientes
#
# - Ocorre quando muitas camadas possuem picos muito pequenos (exemplo, devido a ser sobre uma parte plana da curva tanh)
# - Em redes profundas, atualizações para backpropagation foram perto de 0

# %% [markdown]
# # Validação em Deep Learning
#
# - Comumente usa-se validation split ao invez de cross-validation
# - Deep learning é muito usada em bancos de dados enormes
# - Um score de validação simples é baseado em uma grande quantidade de dados, e é confiável
# - Repetidamente treinando usando cross-validation levaria muito tempo

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuravy'])

# %%
model.fit(predictors, target, validation_split=0.3)

# %% [markdown]
# # Parada inesperada

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping_monitor = EarlyStopping(patience=2)

# %%
model.fit(predictors, target, validation_split=0.3, epochs=20, callbacks = [early_stopping_monitor])

# %% [markdown]
# # Pensando na capacidade do modelo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Workflow para otimização da capacidade do modelo
#
# - Comece com uma dere pequena
# - Gradualmente aumente a capacidade
# - Continue aumentando a capacidade até o score de validação não melhorar mais

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Próximos Passos

# %% [markdown]
# - Começar com problemas de predição padrão em tabelas de números
# - Imagens (com convolucional neural networks)
# - keras.io para ótima documentação
# - Graphicas processing units (GPU) provê melhoras dramáticas no tempo de treinamento dos modelos
# - Necessário uma GPU compatível com CUDA
# - Para treinamento use GPUS da núvem: http://bit.ly/2mYQXQb
