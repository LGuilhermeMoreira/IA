# %% [markdown]
# # Trabalhando com Imagens
#
# ## Reconhecimento de digitos escritos a mão
#
# - MNIST dataset
# - 28 x 28 grid representado por 784 valores para cada imagem
# - Valor em cada parte do array representa o tom de cinza do pixel
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Utilize o MINIST dataset para criar um modelo de deep learning que reconheça dígitos
# - Verifique a qualidade dos dados
# - Crie uma arquitetura simples inicial com apenas uma camada escondida para realizar um primeiro treinamento
# - Utilize as funções de ativação tanh e relu na sua arquitetura e compare resultados variando a taxa de aprendizagem para otimizar o modelo
# - Trabalhe com Stocastic Gradient Descent e Adam para otimizar a função de perda
# - Trabalhe com o aumento da capacidade da rede neural para melhorar sua performance
# - Entrega até 15/03/2020 submetendo o notebook pelo sippa.
